# %% [markdown]
# # Step 1 -  Load and EDA
# - here we load the data and perfrom EDA
# - for checking the null values and dtypes

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data.csv')
df.head()
# Out:
#    invoice_id customer_id transaction_date product_id  quantity  unit_price  \
# 0  INV0079407      C02045       2023-01-01       P048         2        8584
# 1  INV0581190      C14584       2023-01-01       P090         4        7779
# 2  INV0410888      C10301       2023-01-01       P043         5        6183
# 3  INV0429115      C10733       2023-01-01       P085         5          14
# 4  INV0020948      C00558       2023-01-01       P006         5       15309
#
#    total  discount_rate  refund_flag payment_method  country
# 0  17168           0.14            0           Card  Germany
# 1  31118           0.16            0           Card       UK
# 2  30913           0.32            0           Card       US
# 3     68           0.39            0           Card    India
# 4  76547           0.24            0            UPI       US

# %%
df.info()    # We can check Dtype and Null values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 793351 entries, 0 to 793350
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   invoice_id        793351 non-null  object
#  1   customer_id       793351 non-null  object
#  2   transaction_date  793351 non-null  object
#  3   product_id        793351 non-null  object
#  4   quantity          793351 non-null  int64
#  5   unit_price        793351 non-null  int64
#  6   total             793351 non-null  int64
#  7   discount_rate     793351 non-null  float64
#  8   refund_flag       793351 non-null  int64
#  9   payment_method    793351 non-null  object
#  10  country           793351 non-null  object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 66.6+ MB

# %%
df.isnull().sum()      # To chechk null values
# Out:
# invoice_id          0
# customer_id         0
# transaction_date    0
# product_id          0
# quantity            0
# unit_price          0
# total               0
# discount_rate       0
# refund_flag         0
# payment_method      0
# country             0
# dtype: int64

# %%
df.nunique()      # Helps to understand how many customer's  data here and same for another columns
# Out:
# invoice_id          793351
# customer_id          19970
# transaction_date       720
# product_id             100
# quantity                 5
# unit_price           20759
# total                70391
# discount_rate           41
# refund_flag              2
# payment_method           5
# country                 10
# dtype: int64

# %%
df.describe()   # For STD, count, mean.....
# Out:
#             quantity     unit_price          total  discount_rate  \
# count  793351.000000  793351.000000  793351.000000  793351.000000
# mean        3.001179    6321.968230   18964.420942       0.200107
# std         1.414622    5367.747432   19925.866928       0.115571
# min         1.000000       5.000000       5.000000       0.000000
# 25%         2.000000    1879.000000    4053.000000       0.100000
# 50%         3.000000    5162.000000   12487.000000       0.200000
# 75%         4.000000    9683.000000   27613.000000       0.300000
# max         5.000000   21000.000000  105000.000000       0.400000
#
#          refund_flag
# count  793351.000000
# mean        0.055127
# std         0.228228
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000

# %%
# We can see that here date is in string so we have to convert it

df['transaction_date'] = pd.to_datetime(df['transaction_date'])

# %% [markdown]
# # Step 2 - Clean the transaction

# %%
df.duplicated()    # here we have no duplicates
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 793346    False
# 793347    False
# 793348    False
# 793349    False
# 793350    False
# Length: 793351, dtype: bool

# %%
df.drop_duplicates()
# Out:
#         invoice_id customer_id transaction_date product_id  quantity  \
# 0       INV0079407      C02045       2023-01-01       P048         2
# 1       INV0581190      C14584       2023-01-01       P090         4
# 2       INV0410888      C10301       2023-01-01       P043         5
# 3       INV0429115      C10733       2023-01-01       P085         5
# 4       INV0020948      C00558       2023-01-01       P006         5
# ...            ...         ...              ...        ...       ...
# 793346  INV0347654      C08778       2024-12-20       P008         4
# 793347  INV0636071      C15947       2024-12-20       P091         5
# 793348  INV0135655      C03465       2024-12-20       P025         2
# 793349  INV0289587      C07292       2024-12-20       P001         4
# 793350  INV0443504      C11062       2024-12-20       P035         4
#
#         unit_price  total  discount_rate  refund_flag payment_method  country
# 0             8584  17168           0.14            0           Card  Germany
# 1             7779  31118           0.16            0           Card       UK
# 2             6183  30913           0.32            0           Card       US
# 3               14     68           0.39            0           Card    India
# 4            15309  76547           0.24            0            UPI       US
# ...            ...    ...            ...          ...            ...      ...
# 793346        1399   5594           0.15            0           Card       UK
# 793347       13561  67804           0.05            0         PayPal       UK
# 793348       12339  24677           0.04            0         PayPal       UK
# 793349       11326  45305           0.11            0           Card       US
# 793350       16480  65919           0.01            0           Card       UK
#
# [793351 rows x 11 columns]

# %%
# here we have to create a revenue column which is IMP 

df['revenue'] = df['total'] * (1 - df['discount_rate'])

# %%
df = df[df['refund_flag'] == 0]         # So it removes the data who refunded so we don't have revenue of them

# %%
df.head()
# Out:
#    invoice_id customer_id transaction_date product_id  quantity  unit_price  \
# 0  INV0079407      C02045       2023-01-01       P048         2        8584
# 1  INV0581190      C14584       2023-01-01       P090         4        7779
# 2  INV0410888      C10301       2023-01-01       P043         5        6183
# 3  INV0429115      C10733       2023-01-01       P085         5          14
# 4  INV0020948      C00558       2023-01-01       P006         5       15309
#
#    total  discount_rate  refund_flag payment_method  country   revenue
# 0  17168           0.14            0           Card  Germany  14764.48
# 1  31118           0.16            0           Card       UK  26139.12
# 2  30913           0.32            0           Card       US  21020.84
# 3     68           0.39            0           Card    India     41.48
# 4  76547           0.24            0            UPI       US  58175.72
